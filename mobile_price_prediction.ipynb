# %% [markdown]
# <a href="https://colab.research.google.com/github/Gangalaxmi04/Alegeria-Forest-Fire/blob/main/mobile_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/train.csv")

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
model=Sequential([Dense(64,activation='relu',input_shape=(x_train.shape[1],)),Dropout(0.5),Dense(32,activation='relu'),Dropout(0.5),Dense(4,activation='softmax')])

# %%
# prompt: model.compile

model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,epochs=40,batch_size=32,validation_data=(x_test,y_test))
# Out:
# Epoch 1/40
# 50/50 [==============================] - 1s 7ms/step - loss: 1.5546 - accuracy: 0.2700 - val_loss: 1.3141 - val_accuracy: 0.4175
# Epoch 2/40
# 50/50 [==============================] - 0s 3ms/step - loss: 1.3787 - accuracy: 0.3288 - val_loss: 1.2420 - val_accuracy: 0.5300
# Epoch 3/40
# 50/50 [==============================] - 0s 2ms/step - loss: 1.3177 - accuracy: 0.3825 - val_loss: 1.1463 - val_accuracy: 0.5775
# Epoch 4/40
# 50/50 [==============================] - 0s 2ms/step - loss: 1.2128 - accuracy: 0.4481 - val_loss: 1.0273 - val_accuracy: 0.6375
# Epoch 5/40
# 50/50 [==============================] - 0s 3ms/step - loss: 1.1148 - accuracy: 0.4931 - val_loss: 0.8977 - val_accuracy: 0.6700
# Epoch 6/40
# 50/50 [==============================] - 0s 3ms/step - loss: 1.0152 - accuracy: 0.5263 - val_loss: 0.7962 - val_accuracy: 0.7000
# Epoch 7/40
# ...

# %%
loss=model.evaluate(x_test,y_test)
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2044 - accuracy: 0.9350

# %%
loss
# Out:
# [0.2043955773115158, 0.9350000023841858]

# %%
predictionbs=model.predict(x_test)
# Out:
# 13/13 [==============================] - 0s 1ms/step

# %%
model.save('model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
